# %%
# Setup
import sys
from pathlib import Path

project_root = Path.cwd().parent
sys.path.insert(0, str(project_root))

from src.data.datasets import CNNIberFireDataset
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt

ZARR_PATH = project_root / "data" / "silver" / "IberFire.zarr"
print(f"Project root: {project_root}")
print(f"Zarr path exists: {ZARR_PATH.exists()}")
# Out:
# Project root: /Users/vladimir/catalonia-wildfire-prediction
# Zarr path exists: True

# %%
from src.data.datasets import SimpleIberFireSegmentationDataset
from torch.utils.data import DataLoader

feature_vars = [
    "wind_speed_mean",
    "t2m_mean",
    "RH_mean",
    "total_precipitation_mean",
]

train_ds = SimpleIberFireSegmentationDataset(
    zarr_path=ZARR_PATH,
    time_start="2018-01-01",
    time_end="2020-12-31",
    feature_vars=feature_vars,
    label_var="is_near_fire",
    spatial_downsample=4,
    lead_time=1,         # predict tomorrow
    compute_stats=True,  # or precompute & pass stats
)

train_loader = DataLoader(
    train_ds,
    batch_size=2,        # start small, check memory
    shuffle=True,
    num_workers=0,
)
# Out:
# [SimpleDataset] Opening Zarr dataset: /Users/vladimir/catalonia-wildfire-prediction/data/silver/IberFire.zarr
# [SimpleDataset] Filtering time range: 2018-01-01 to 2020-12-31
# ---------------------------------------------------------------------------
# DTypePromotionError                       Traceback (most recent call last)
# DTypePromotionError: The DType <class 'numpy.dtypes.Int64DType'> could not be promoted by <class 'numpy.dtypes.DateTime64DType'>. This means that no common DType exists for the given inputs. For example they cannot be stored in a single array unless the dtype is `object`. The full list of DTypes is: (<class 'numpy.dtypes.Int64DType'>, <class 'numpy.dtypes.DateTime64DType'>)
#
# The above exception was the direct cause of the following exception:
#
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[3], line 11
#       2 from torch.utils.data import DataLoader
#       4 feature_vars = [
#       5     "wind_speed_mean",
#       6     "t2m_mean",
#       7     "RH_mean",
#       8     "total_precipitation_mean",
#       9 ]
# ---> 11 train_ds = SimpleIberFireSegmentationDataset(
#      12     zarr_path=ZARR_PATH,
#      13     time_start="2018-01-01",
#      14     time_end="2020-12-31",
#      15     feature_vars=feature_vars,
#      16     label_var="is_near_fire",
#      17     spatial_downsample=4,
#      18     lead_time=1,         # predict tomorrow
#      19     compute_stats=True,  # or precompute & pass stats
#      20 )
#      22 train_loader = DataLoader(
#      23     train_ds,
#      24     batch_size=2,        # start small, check memory
#      25     shuffle=True,
#      26     num_workers=0,
#      27 )
#
# File ~/catalonia-wildfire-prediction/src/data/datasets.py:337, in SimpleIberFireSegmentationDataset.__init__(self, zarr_path, time_start, time_end, feature_vars, label_var, spatial_downsample, lead_time, stats, compute_stats)
#     335 print(f"[SimpleDataset] Filtering time range: {time_start} to {time_end}")
#     336 time = self.root["time"][:]
# --> 337 mask = (time >= np.datetime64(time_start)) & (time <= np.datetime64(time_end))
#     338 all_indices = np.where(mask)[0]
#     340 # Ensure we can look ahead by lead_time
#
# UFuncTypeError: ufunc 'greater_equal' did not contain a loop with signature matching types (<class 'numpy.dtypes.Int64DType'>, <class 'numpy.dtypes.DateTime64DType'>) -> None
