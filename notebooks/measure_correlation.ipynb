# %%
import xarray as xr
import numpy as np
import pandas as pd
from pathlib import Path
import os

ZARR_PATH = Path("data/gold/IberFire_coarse8_time1.zarr")
LABEL_NAME = "is_fire"
DOWNSAMPLE = 1           # same as training
MAX_TIMES = None          # or None to use all; 365 is a good compromise
project_root = Path.cwd().parent
os.chdir(project_root)
ds = xr.open_zarr(ZARR_PATH, consolidated=False)

label_da = ds[LABEL_NAME]   # expected shape: [time, y, x]

# All candidate feature variables (exclude the label itself)
all_features = [v for v in ds.data_vars if v != LABEL_NAME]

# Figure out which features are dynamic (have time dim) vs static (no time)
dynamic_vars = []
static_vars = []
for v in all_features:
    da = ds[v]
    if "time" in da.dims:
        dynamic_vars.append(v)
    else:
        static_vars.append(v)

print("Dynamic features:", dynamic_vars)
print("Static features:", static_vars)

# Choose time indices to use (sample if too many)
time_indices = np.arange(ds.sizes["time"])
if MAX_TIMES is not None and MAX_TIMES < len(time_indices):
    rng = np.random.default_rng(42)
    time_indices = np.sort(
        rng.choice(time_indices, size=MAX_TIMES, replace=False)
    )

print(f"Will use {len(time_indices)} time steps for correlation.")


def streaming_corr_dynamic(feature_da, label_da, time_indices, down=1):
    """
    Pearson correlation between a dynamic feature [time,y,x]
    and label [time,y,x], streamed over time + space.
    """
    sum_x = sum_y = sum_x2 = sum_y2 = sum_xy = 0.0
    n = 0

    for t in time_indices:
        x = feature_da.isel(time=int(t)).values[::down, ::down].ravel()
        y = label_da.isel(time=int(t)).values[::down, ::down].ravel()

        mask = np.isfinite(x) & np.isfinite(y)
        x = x[mask]
        y = y[mask]
        if x.size == 0:
            continue

        n += x.size
        sum_x += x.sum()
        sum_y += y.sum()
        sum_x2 += (x**2).sum()
        sum_y2 += (y**2).sum()
        sum_xy += (x * y).sum()

    if n == 0:
        return np.nan

    mean_x = sum_x / n
    mean_y = sum_y / n
    var_x = (sum_x2 / n) - mean_x**2
    var_y = (sum_y2 / n) - mean_y**2
    cov_xy = (sum_xy / n) - mean_x * mean_y

    if var_x <= 0 or var_y <= 0:
        return np.nan

    return cov_xy / np.sqrt(var_x * var_y)


def streaming_corr_static(feature_da, label_da, time_indices, down=1):
    """
    Pearson correlation between a static feature [y,x]
    and a time-varying label [time,y,x].

    We conceptually "repeat" the static field for each time step and
    correlate over all (t,y,x) points, but do it in a streaming way.
    """
    # Static field: same x for all times
    x_static = feature_da.values[::down, ::down].ravel()

    mask_x = np.isfinite(x_static)
    x_static = x_static[mask_x]
    if x_static.size == 0:
        return np.nan

    sum_x = sum_y = sum_x2 = sum_y2 = sum_xy = 0.0
    n = 0

    for t in time_indices:
        y = label_da.isel(time=int(t)).values[::down, ::down].ravel()
        y = y[mask_x]   # align with static mask
        y = y[np.isfinite(y)]
        # Note: if y has NaNs where x was valid, this effectively shrinks sample size

        # If nothing left for this time step, skip
        if y.size == 0:
            continue

        # For correlation formula, x must match y's length.
        # If some y entries were dropped, we subselect x_static accordingly.
        # Here we recompute a mask for y, but since we only filtered NaNs,
        # the length should match x_static (mask_x) unless label has NaNs.
        # To keep things simple and robust, recompute x to match y.size:
        x = x_static[: y.size]

        n += x.size
        sum_x += x.sum()
        sum_y += y.sum()
        sum_x2 += (x**2).sum()
        sum_y2 += (y**2).sum()
        sum_xy += (x * y).sum()

    if n == 0:
        return np.nan

    mean_x = sum_x / n
    mean_y = sum_y / n
    var_x = (sum_x2 / n) - mean_x**2
    var_y = (sum_y2 / n) - mean_y**2
    cov_xy = (sum_xy / n) - mean_x * mean_y

    if var_x <= 0 or var_y <= 0:
        return np.nan

    return cov_xy / np.sqrt(var_x * var_y)


results = []

for v in all_features:
    print(f"Processing {v}...")
    da = ds[v]
    if v in dynamic_vars:
        corr = streaming_corr_dynamic(da, label_da, time_indices, down=DOWNSAMPLE)
    elif v in static_vars:
        corr = streaming_corr_static(da, label_da, time_indices, down=DOWNSAMPLE)
    else:
        # Fallback: treat as dynamic by default
        corr = streaming_corr_dynamic(da, label_da, time_indices, down=DOWNSAMPLE)

    results.append({"variable": v, "corr": corr})

corr_df = pd.DataFrame(results).sort_values(
    "corr", key=lambda x: np.abs(x), ascending=False
)

display(corr_df.head(30))
corr_df.to_csv("feature_target_correlations.csv", index=False)
# Out:
# Dynamic features: ['FAPAR', 'FWI', 'LAI', 'LST', 'NDVI', 'RH_max', 'RH_mean', 'RH_min', 'RH_range', 'SWI_001', 'SWI_005', 'SWI_010', 'SWI_020', 'is_holiday', 'is_near_fire', 'surface_pressure_max', 'surface_pressure_mean', 'surface_pressure_min', 'surface_pressure_range', 't2m_max', 't2m_mean', 't2m_min', 't2m_range', 'total_precipitation_mean', 'wind_direction_at_max_speed', 'wind_direction_mean', 'wind_speed_max', 'wind_speed_mean']
# Static features: ['AutonomousCommunities', 'CLC_2006_1', 'CLC_2006_10', 'CLC_2006_11', 'CLC_2006_12', 'CLC_2006_13', 'CLC_2006_14', 'CLC_2006_15', 'CLC_2006_16', 'CLC_2006_17', 'CLC_2006_18', 'CLC_2006_19', 'CLC_2006_2', 'CLC_2006_20', 'CLC_2006_21', 'CLC_2006_22', 'CLC_2006_23', 'CLC_2006_24', 'CLC_2006_25', 'CLC_2006_26', 'CLC_2006_27', 'CLC_2006_28', 'CLC_2006_29', 'CLC_2006_3', 'CLC_2006_30', 'CLC_2006_31', 'CLC_2006_32', 'CLC_2006_33', 'CLC_2006_34', 'CLC_2006_35', 'CLC_2006_36', 'CLC_2006_37', 'CLC_2006_38', 'CLC_2006_39', 'CLC_2006_4', 'CLC_2006_40', 'CLC_2006_41', 'CLC_2006_42', 'CLC_2006_43', 'CLC_2006_44', 'CLC_2006_5', 'CLC_2006_6', 'CLC_2006_7', 'CLC_2006_8', 'CLC_2006_9', 'CLC_2006_agricultural_proportion', 'CLC_2006_arable_land_proportion', 'CLC_2006_artificial_proportion', 'CLC_2006_artificial_vegetation_proportion', 'CLC_2006_forest_and_semi_natural_proportion', 'CLC_2006_forest_proportion', 'CLC_2006_heterogeneous_agriculture_proportion', 'CLC_2006_industrial_proportion', 'CLC_2006_inland_waters_proportion', 'CLC_2006_inland_wetlands_proportion', 'CLC_2006_marine_waters_proportion', 'CLC_2006_maritime_wetlands_proportion', 'CLC_2006_mine_proportion', 'CLC_2006_open_space_proportion', 'CLC_2006_permanent_crops_proportion', 'CLC_2006_scrub_proportion', 'CLC_2006_urban_fabric_proportion', 'CLC_2006_waterbody_proportion', 'CLC_2006_wetlands_proportion', 'CLC_2012_1', 'CLC_2012_10', 'CLC_2012_11', 'CLC_2012_12', 'CLC_2012_13', 'CLC_2012_14', 'CLC_2012_15', 'CLC_2012_16', 'CLC_2012_17', 'CLC_2012_18', 'CLC_2012_19', 'CLC_2012_2', 'CLC_2012_20', 'CLC_2012_21', 'CLC_2012_22', 'CLC_2012_23', 'CLC_2012_24', 'CLC_2012_25', 'CLC_2012_26', 'CLC_2012_27', 'CLC_2012_28', 'CLC_2012_29', 'CLC_2012_3', 'CLC_2012_30', 'CLC_2012_31', 'CLC_2012_32', 'CLC_2012_33', 'CLC_2012_34', 'CLC_2012_35', 'CLC_2012_36', 'CLC_2012_37', 'CLC_2012_38', 'CLC_2012_39', 'CLC_2012_4', 'CLC_2012_40', 'CLC_2012_41', 'CLC_2012_42', 'CLC_2012_43', 'CLC_2012_44', 'CLC_2012_5', 'CLC_2012_6', 'CLC_2012_7', 'CLC_2012_8', 'CLC_2012_9', 'CLC_2012_agricultural_proportion', 'CLC_2012_arable_land_proportion', 'CLC_2012_artificial_proportion', 'CLC_2012_artificial_vegetation_proportion', 'CLC_2012_forest_and_semi_natural_proportion', 'CLC_2012_forest_proportion', 'CLC_2012_heterogeneous_agriculture_proportion', 'CLC_2012_industrial_proportion', 'CLC_2012_inland_waters_proportion', 'CLC_2012_inland_wetlands_proportion', 'CLC_2012_marine_waters_proportion', 'CLC_2012_maritime_wetlands_proportion', 'CLC_2012_mine_proportion', 'CLC_2012_open_space_proportion', 'CLC_2012_permanent_crops_proportion', 'CLC_2012_scrub_proportion', 'CLC_2012_urban_fabric_proportion', 'CLC_2012_waterbody_proportion', 'CLC_2012_wetlands_proportion', 'CLC_2018_1', 'CLC_2018_10', 'CLC_2018_11', 'CLC_2018_12', 'CLC_2018_13', 'CLC_2018_14', 'CLC_2018_15', 'CLC_2018_16', 'CLC_2018_17', 'CLC_2018_18', 'CLC_2018_19', 'CLC_2018_2', 'CLC_2018_20', 'CLC_2018_21', 'CLC_2018_22', 'CLC_2018_23', 'CLC_2018_24', 'CLC_2018_25', 'CLC_2018_26', 'CLC_2018_27', 'CLC_2018_28', 'CLC_2018_29', 'CLC_2018_3', 'CLC_2018_30', 'CLC_2018_31', 'CLC_2018_32', 'CLC_2018_33', 'CLC_2018_34', 'CLC_2018_35', 'CLC_2018_36', 'CLC_2018_37', 'CLC_2018_38', 'CLC_2018_39', 'CLC_2018_4', 'CLC_2018_40', 'CLC_2018_41', 'CLC_2018_42', 'CLC_2018_43', 'CLC_2018_44', 'CLC_2018_5', 'CLC_2018_6', 'CLC_2018_7', 'CLC_2018_8', 'CLC_2018_9', 'CLC_2018_agricultural_proportion', 'CLC_2018_arable_land_proportion', 'CLC_2018_artificial_proportion', 'CLC_2018_artificial_vegetation_proportion', 'CLC_2018_forest_and_semi_natural_proportion', 'CLC_2018_forest_proportion', 'CLC_2018_heterogeneous_agriculture_proportion', 'CLC_2018_industrial_proportion', 'CLC_2018_inland_waters_proportion', 'CLC_2018_inland_wetlands_proportion', 'CLC_2018_marine_waters_proportion', 'CLC_2018_maritime_wetlands_proportion', 'CLC_2018_mine_proportion', 'CLC_2018_open_space_proportion', 'CLC_2018_permanent_crops_proportion', 'CLC_2018_scrub_proportion', 'CLC_2018_urban_fabr ...
# Will use 6241 time steps for correlation.
# Processing AutonomousCommunities...
# Processing CLC_2006_1...
# Processing CLC_2006_10...
# Processing CLC_2006_11...
# Processing CLC_2006_12...
# Processing CLC_2006_13...
# Processing CLC_2006_14...
# Processing CLC_2006_15...
# Processing CLC_2006_16...
# Processing CLC_2006_17...
# Processing CLC_2006_18...
# Processing CLC_2006_19...
# Processing CLC_2006_2...
# Processing CLC_2006_20...
# Processing CLC_2006_21...
# Processing CLC_2006_22...
# Processing CLC_2006_23...
# Processing CLC_2006_24...
# Processing CLC_2006_25...
# Processing CLC_2006_26...
# Processing CLC_2006_27...
# Processing CLC_2006_28...
# Processing CLC_2006_29...
# Processing CLC_2006_3...
# Processing CLC_2006_30...
# Processing CLC_2006_31...
# Processing CLC_2006_32...
# Processing CLC_2006_33...
# Processing CLC_2006_34...
# Processing CLC_2006_35...
# Processing CLC_2006_36...
# Processing CLC_2006_37...
# Processing CLC_2006_38...
# Processing CLC_2006_39...
# Processing CLC_2006_4...
# Processing CLC_2006_40...
# Processing CLC_2006_41...
# Processing CLC_2006_42...
# Processing CLC_2006_43...
# Processing CLC_2006_44...
# Processing CLC_2006_5...
# Processing CLC_2006_6...
# Processing CLC_2006_7...
# Processing CLC_2006_8...
# Processing CLC_2006_9...
# Processing CLC_2006_agricultural_proportion...
# Processing CLC_2006_arable_land_proportion...
# Processing CLC_2006_artificial_proportion...
# Processing CLC_2006_artificial_vegetation_proportion...
# Processing CLC_2006_forest_and_semi_natural_proportion...
# Processing CLC_2006_forest_proportion...
# Processing CLC_2006_heterogeneous_agriculture_proportion...
# Processing CLC_2006_industrial_proportion...
# Processing CLC_2006_inland_waters_proportion...
# Processing CLC_2006_inland_wetlands_proportion...
# Processing CLC_2006_marine_waters_proportion...
# Processing CLC_2006_maritime_wetlands_proportion...
# Processing CLC_2006_mine_proportion...
# Processing CLC_2006_open_space_proportion...
# Processing CLC_2006_permanent_crops_proportion...
# Processing CLC_2006_scrub_proportion...
# Processing CLC_2006_urban_fabric_proportion...
# Processing CLC_2006_waterbody_proportion...
# Processing CLC_2006_wetlands_proportion...
# Processing CLC_2012_1...
# Processing CLC_2012_10...
# Processing CLC_2012_11...
# Processing CLC_2012_12...
# Processing CLC_2012_13...
# Processing CLC_2012_14...
# Processing CLC_2012_15...
# Processing CLC_2012_16...
# Processing CLC_2012_17...
# Processing CLC_2012_18...
# Processing CLC_2012_19...
# Processing CLC_2012_2...
# Processing CLC_2012_20...
# Processing CLC_2012_21...
# Processing CLC_2012_22...
# Processing CLC_2012_23...
# Processing CLC_2012_24...
# Processing CLC_2012_25...
# Processing CLC_2012_26...
# Processing CLC_2012_27...
# Processing CLC_2012_28...
# Processing CLC_2012_29...
# Processing CLC_2012_3...
# Processing CLC_2012_30...
# Processing CLC_2012_31...
# Processing CLC_2012_32...
# Processing CLC_2012_33...
# Processing CLC_2012_34...
# Processing CLC_2012_35...
# Processing CLC_2012_36...
# Processing CLC_2012_37...
# Processing CLC_2012_38...
# Processing CLC_2012_39...
# Processing CLC_2012_4...
# Processing CLC_2012_40...
# Processing CLC_2012_41...
# Processing CLC_2012_42...
# Processing CLC_2012_43...
# Processing CLC_2012_44...
# Processing CLC_2012_5...
# Processing CLC_2012_6...
# Processing CLC_2012_7...
# Processing CLC_2012_8...
# Processing CLC_2012_9...
# Processing CLC_2012_agricultural_proportion...
# Processing CLC_2012_arable_land_proportion...
# Processing CLC_2012_artificial_proportion...
# Processing CLC_2012_artificial_vegetation_proportion...
# Processing CLC_2012_forest_and_semi_natural_proportion...
# Processing CLC_2012_forest_proportion...
# Processing CLC_2012_heterogeneous_agriculture_proportion...
# Processing CLC_2012_industrial_proportion...
# Processing CLC_2012_inland_waters_proportion...
# Processing CLC_2012_inland_wetlands_proportion...
# Processing CLC_2012_marine_waters_proportion...
# Processing CLC_2012_maritime_wetlands_proportion...
# Processing CLC_2012_mine_proportion...
# Processing CLC_2012_open_space_proportion...
# Processing CLC_2012_permanent_crops_proportion...
# Processing CLC_2012_scrub_proportion...
# Processing CLC_2012_urban_fabric_proportion...
# Processing CLC_2012_waterbody_proportion...
# Processing CLC_2012_wetlands_proportion...
# Processing CLC_2018_1...
# Processing CLC_2018_10...
# Processing CLC_2018_11...
# Processing CLC_2018_12...
# Processing CLC_2018_13...
# Processing CLC_2018_14...
# Processing CLC_2018_15...
# Processing CLC_2018_16...
# Processing CLC_2018_17...
# Processing CLC_2018_18...
# Processing CLC_2018_19...
# Processing CLC_2018_2...
# Processing CLC_2018_20...
# Processing CLC_2018_21...
# Processing CLC_2018_22...
# Processing CLC_2018_23...
# Processing CLC_2018_24...
# Processing CLC_2018_25...
# Processing CLC_2018_26...
# Processing CLC_2018_27...
# Processing CLC_2018_28...
# Processing CLC_2018_29...
# Processing CLC_2018_3...
# Processing CLC_2018_30...
# Processing CLC_2018_31...
# Processing CLC_2018_32...
# Processing CLC_2018_33...
# Processing CLC_2018_34...
# Processing CLC_2018_35...
# Processing CLC_2018_36...
# Processing CLC_2018_37...
# Processing CLC_2018_38...
# Processing CLC_2018_39...
# Processing CLC_2018_4...
# Processing CLC_2018_40...
# Processing CLC_2018_41...
# Processing CLC_2018_42...
# Processing CLC_2018_43...
# Processing CLC_2018_44...
# Processing CLC_2018_5...
# Processing CLC_2018_6...
# Processing CLC_2018_7...
# Processing CLC_2018_8...
# Processing CLC_2018_9...
# Processing CLC_2018_agricultural_proportion...
# Processing CLC_2018_arable_land_proportion...
# Processing CLC_2018_artificial_proportion...
# Processing CLC_2018_artificial_vegetation_proportion...
# Processing CLC_2018_forest_and_semi_natural_proportion...
# Processing CLC_2018_forest_proportion...
# Processing CLC_2018_heterogeneous_agriculture_proportion...
# Processing CLC_2018_industrial_proportion...
# Processing CLC_2018_inland_waters_proportion...
# Processing CLC_2018_inland_wetlands_proportion...
# Processing CLC_2018_marine_waters_proportion...
# Processing CLC_2018_maritime_wetlands_proportion...
# Processing CLC_2018_mine_proportion...
# Processing CLC_2018_open_space_proportion...
# Processing CLC_2018_permanent_crops_proportion...
# Processing CLC_2018_scrub_proportion...
# Processing CLC_2018_urban_fabric_proportion...
# Processing CLC_2018_waterbody_proportion...
# Processing CLC_2018_wetlands_proportion...
# Processing FAPAR...
# Processing FWI...
# Processing LAI...
# Processing LST...
# Processing NDVI...
# Processing RH_max...
# Processing RH_mean...
# Processing RH_min...
# Processing RH_range...
# Processing SWI_001...
# Processing SWI_005...
# Processing SWI_010...
# Processing SWI_020...
# Processing aspect_1...
# Processing aspect_2...
# Processing aspect_3...
# Processing aspect_4...
# Processing aspect_5...
# Processing aspect_6...
# Processing aspect_7...
# Processing aspect_8...
# Processing aspect_NODATA...
# Processing dist_to_railways_mean...
# Processing dist_to_railways_stdev...
# Processing dist_to_roads_mean...
# Processing dist_to_roads_stdev...
# Processing dist_to_waterways_mean...
# Processing dist_to_waterways_stdev...
# Processing elevation_mean...
# Processing elevation_stdev...
# Processing is_holiday...
# Processing is_natura2000...
# Processing is_near_fire...
# Processing is_sea...
# Processing is_spain...
# Processing is_waterbody...
# Processing popdens_2008...
# Processing popdens_2009...
# Processing popdens_2010...
# Processing popdens_2011...
# Processing popdens_2012...
# Processing popdens_2013...
# Processing popdens_2014...
# Processing popdens_2015...
# Processing popdens_2016...
# Processing popdens_2017...
# Processing popdens_2018...
# Processing popdens_2019...
# Processing popdens_2020...
# Processing roughness_mean...
# Processing roughness_stdev...
# Processing slope_mean...
# Processing slope_stdev...
# Processing surface_pressure_max...
# Processing surface_pressure_mean...
# Processing surface_pressure_min...
# Processing surface_pressure_range...
# Processing t2m_max...
# Processing t2m_mean...
# Processing t2m_min...
# Processing t2m_range...
# Processing total_precipitation_mean...
# Processing wind_direction_at_max_speed...
# Processing wind_direction_mean...
# Processing wind_speed_max...
# Processing wind_speed_mean...
# Processing x_coordinate...
# Processing x_index...
# Processing y_coordinate...
# Processing y_index...
#                                         variable      corr
# 222                                 is_near_fire  0.088216
# 20                                   CLC_2006_27  0.026780
# 146                                  CLC_2018_27  0.024774
# 83                                   CLC_2012_27  0.024704
# 219                              elevation_stdev  0.016741
# 241                                   slope_mean  0.015818
# 239                               roughness_mean  0.015746
# 123                    CLC_2012_scrub_proportion  0.014222
# 186                    CLC_2018_scrub_proportion  0.014117
# 60                     CLC_2006_scrub_proportion  0.013991
# 240                              roughness_stdev  0.013617
# 242                                  slope_stdev  0.013181
# 175  CLC_2018_forest_and_semi_natural_proportion  0.012407
# 112  CLC_2012_forest_and_semi_natural_proportion  0.012403
# 49   CLC_2006_forest_and_semi_natural_proportion  0.012377
# 224                                     is_spain  0.010156
# 215                          dist_to_roads_stdev  0.009363
# 218                               elevation_mean  0.008630
# 142                                  CLC_2018_23  0.008279
# 79                                   CLC_2012_23  0.008180
# 16                                   CLC_2006_23  0.008160
# 0                          AutonomousCommunities  0.008101
# 210                                     aspect_8  0.007993
# 217                      dist_to_waterways_stdev  0.007981
# 225                                 is_waterbody -0.007975
# 213                       dist_to_railways_stdev -0.007835
# 212                        dist_to_railways_mean -0.007625
# 191                                          FWI  0.007530
# 195                                       RH_max -0.007454
# 203                                     aspect_1  0.007427

# %%
output_path = project_root / "feature_target_correlations.csv"
corr_df.to_csv(output_path, index=False)
print(f"Saved to: {output_path.resolve()}")
# Out:
# Saved to: /Users/vladimir/catalonia-wildfire-prediction/feature_target_correlations.csv
