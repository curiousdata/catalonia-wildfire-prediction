# %% [markdown]
# code to create a SpatialImageDataset class to handle a NetCDF data as an array of images without the temporal dimensions - for CNN model.

# %%
import xarray as xr
import pandas as pd
import numpy as np
from pathlib import Path
import torch
from torch.utils.data import Dataset, DataLoader
from pathlib import Path
from typing import List, Optional, Tuple
DATASET_PATH = Path("data/IberFire.nc")

# %%
class SpatialImageDataset(Dataset):
